# %%
# !pip install rasa==1.10.3

# %%
# !pip install -U tables==3.6.1

# %%
# !pip install -U ipython

# %%
# !python -m spacy download en

# !pip install nest_asyncio==1.3.3
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz
# ...

# %%
import os
import rasa
import nest_asyncio

nest_asyncio.apply()
print(" ready.")
# Out:
#  ready.

# %%
from rasa.cli.scaffold import create_initial_project
project = "test-project"
create_initial_project(project)
# move into project directory and show files
os.chdir(project)
print(os.listdir("."))
# Out:
# ['actions.py', 'credentials.yml', 'config.yml', 'tests', '__pycache__', 'domain.yml', '__init__.py', 'endpoints.yml', 'data']

# %%
# %%writefile /content/test-project/data/nlu.md
# ## intent:sleepy
# - how to i get to sleep
# - i can't sleep
# - insomia
# - How can i fall asleep
#
# ## intent:stress
# - how to deal with pressure
# - how to deal with stress
# - i'm stressed
# - How can i chosse a good environment to work on
# - i'm depressed
# - pressure
# - i' m exhausted
# - i feel tired
# - bored
#
# ## intent:diabets
# - diabets
# - diabets symptoms
# - diabets signs
# - what are diabets signs
# - diabets check
#
# ## intent:headache-one-day
# - just today
# - today
# - all long day
# - this night
# - now
# - right now
#
# ## intent:headache-num-days
# - since [2](number) days
# - since [3](number) days
# - [2](number) days ago
# - [3](number) days
# - [2](number) days
# - i forgot
# ## intent:headache
# - why do i wake up with headache ?
# - headache
# - how do i stop headache ?
# - stop headache
# - i have migraine
# - how do i stop migraine?
# - headache treatement
# - headache medication
#
# ## intent:covid
# - covid symptoms
# - covid
# - do i have covid ?
# - covid signs
#
# ## intent:greet
# - hey
# - hello
# - hi
# - good morning
# - good evening
# - hey there
#
# ## intent:goodbye
# - bye
# - goodbye
# - see you around
# - see you later
#
# ## intent:affirm
# - yes
# - indeed
# - of course
# - that sounds good
# - correct
#
# ## intent:deny
# - no
# - never
# - I don't think so
# - don't like that
# - no way
# - not really
#
# ## intent:mood_great
# - perfect
# - very good
# - great
# - amazing
# - wonderful
# - I am feeling very good
# - I am great
# - I'm good
# - fine
# ## intent:mood_unhappy
# - sad
# - very sad
# - unhappy
# - bad
# - very bad
# - awful
# - terrible
# - not very good
# - extremely sad
# - so sad
#
# ## intent:bot_challenge
# - are you a bot?
# - are you a human?
# - am I talking to a bot?
# - am I talking to a human?
# Out:
# Overwriting /content/test-project/data/nlu.md

# %%
# %%writefile /content/test-project/domain.yml
# intents:
#   - greet
#   - goodbye
#   - affirm
#   - deny
#   - mood_great
#   - mood_unhappy
#   - bot_challenge
#   - covid
#   - headache
#   - headache-num-days
#   - headache-one-day
#   - diabets
#   - stress
#   - sleepy
#
# responses:
#   utter_sleepy1:
#   - text: "If you really seek relaxation you may need to drop down this laptop at first . All you need actually is a quiet environment with some quiet music.Next, for only sleepig maaters ,you should have a passive attitude it means Accepting that it’s normal for your mind to wander allows you to remain at-ease "
#
#   utter_sleepy2:
#   - text: "Here is some tips :  Option 1 : Counting Breaths  Option 2 : Try Visualizing a peaceful image from your past and all of its details engages your attention in order to promote relaxation"
#
#   utter_stress1:
#   - text: "To begin, you need to understand the situation and its gravity.Admitting that you are depressed is the first step to relief.Then, it's ok to have one day relief when you can do nothing ,just what you want . being positive is not easy but you have to be surrounded by optimistic peaple."
#
#   utter_stress2:
#   - text: "Try to exercice reguraly ,sleep, avoid nagging, eat healthy food and set realistic goals every day.Remember you're not a robot (like me hahaha).It's ok when you are stuck at second gear just keep trying "
#
#   utter_diabets:
#   - text: "If you always feel thirsty or hungry or you want very often to urinate you must check your doctor for blood glucose test (while fasting)"
#
#   utter_headache:
#   - text: "since when"
#
#   utter_headache-sol1:
#   - text: "You should rest in a quiet dark room at least for 5 minutes.If that dosen't wrok try some medications such as Efferalgan ,Ibuprafeine... For other details, you can surf our website"
#
#   utter_headache-sol2:
#   - text: "Dim the Lights , Get Some Caffeine and if your head still hurts you can surf our website for adequat medication"
#
#   utter_covid:
#   - text: "The most common symptomps of Covid_19 are fever,cough,tiredness,loss of taste or smell,difficulty breathing or shortness of breath...If you are looking for covid_19 tests you can click on Covid up on the navbar side"
#
#   utter_greet:
#   - text: "Hey! How are you?"
#
#   utter_cheer_up:
#   - text: "Here is something to cheer you up:"
#     image: "https://i.imgur.com/nGF1K8f.jpg"
#
#   utter_did_that_help:
#   - text: "Did that help you?"
#
#   utter_happy:
#   - text: "Great, carry on!"
#
#   utter_goodbye:
#   - text: "Bye"
#
#   utter_iamabot:
#   - text: "I am a bot, powered by Rasa."
# entities:
#  - number
# session_config:
#   session_expiration_time: 60
#   carry_over_slots_to_new_session: true
# Out:
# Overwriting /content/test-project/domain.yml

# %%
# %%writefile /content/test-project/data/stories.md
# ## sleep management 1
# * sleepy
#   - utter_sleepy1
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## sleep management 2
# * sleepy
#   - utter_sleepy1
#   - utter_did_that_help
# * deny
#   - utter_sleepy2
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
#
# ## stress management 1
# * stress
#   - utter_stress1
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## stress management 2
# * stress
#   - utter_stress1
#   - utter_did_that_help
# * deny
#   - utter_stress2
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## covid treatment
# * greet
#   - utter_greet
# * covid
#   - utter_covid
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## diabet
# * diabets
#   - utter_diabets
#
# ## headache treatment 2
# * greet
#   - utter_greet
# * headache
#   - utter_headache
# * headache-one-day
#   - utter_headache-sol2
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## headache treatment 1
# * greet
#   - utter_greet
# * headache
#   - utter_headache
# * headache-num-days
#   - utter_headache-sol1
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## happy path
# * greet
#   - utter_greet
# * mood_great
#   - utter_happy
#
# ## sad path 1
# * greet
#   - utter_greet
# * mood_unhappy
#   - utter_cheer_up
#   - utter_did_that_help
# * affirm
#   - utter_happy
#
# ## sad path 2
# * greet
#   - utter_greet
# * mood_unhappy
#   - utter_cheer_up
#   - utter_did_that_help
# * deny
#   - utter_goodbye
#
# ## say goodbye
# * goodbye
#   - utter_goodbye
#
# ## bot challenge
# * bot_challenge
#   - utter_iamabot
# Out:
# Overwriting /content/test-project/data/stories.md

# %%
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
print(config, training_files, domain, output)
# Out:
# config.yml data/ domain.yml models/

# %%
model_path = rasa.train(domain, config, [training_files], output)
print(model_path)
# Out:
# Training Core model...
# ...
# Processed trackers: 100%|██████████| 13/13 [00:00<00:00, 99.71it/s, # actions=55]
# Processed actions: 55it [00:00, 562.05it/s, # examples=55]
# ...
# Epochs: 100%|██████████| 100/100 [00:50<00:00,  1.98it/s, t_loss=0.106, loss=0.007, acc=1.000]
# Core model training completed.
# Training NLU model...
# Epochs: 100%|██████████| 100/100 [00:41<00:00,  2.42it/s, t_loss=2.303, i_loss=0.587, entity_loss=0.013, i_acc=1.000, entity_f1=0.919]
# NLU model training completed.
# Your Rasa model is trained and saved at '/content/test-project/models/20220518-192745.tar.gz'.
# models/20220518-192745.tar.gz

# %%
from rasa.jupyter import chat

endpoints = 'endpoints.yml'

chat(model_path, endpoints)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/array_grad.py:563: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# Your bot is ready to talk! Type your messages here or send '/stop'.
# Hey! How are you?
# Here is something to cheer you up:
# <img src="https://i.imgur.com/nGF1K8f.jpg"/>
# Did that help you?
# Great, carry on!
# since when
# Dim the Lights , Get Some Caffeine and if your head still hurts you can surf our website for adequat medication
# Did that help you?
# Great, carry on!
# since when
# You should rest in a quiet dark room at least for 5 minutes.If that dosen't wrok try some medications such as Efferalgan ,Ibuprafeine... For other details, you can surf our website
# Did that help you?
# Great, carry on!
# ...
